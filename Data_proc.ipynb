# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
play_store = pd.read_csv('googleplaystore.csv')
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
play_store.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# as we know the rating coulmn cant be more than 5 then we will find a way to negate the rows that have rating more than 5 so we can replace them with the mean of the rating column
play_store[play_store['Rating'] > 5]
rating_mean = play_store['Rating'].mean()
play_store[play_store['Rating'] > 5] = rating_mean

# %%
play_store.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.191758
# std       0.515191
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
play_store['Rating'].isnull().sum()
play_store['Rating'].fillna(rating_mean, inplace=True)
# after this lines of code we fixed the rating coulmn now moving to the size coulmn to fix it
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4672\1615404445.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   play_store['Rating'].fillna(rating_mean, inplace=True)

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
play_store['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %%
# Fixing the size column 
# first we will make a function to convert the size to numeric
def converting_size_to_numeric(size):
    if not isinstance(size, str):
        return np.nan
    
    size = size.strip().upper()
    if size.endswith('M'):
        try:
            return float(size[:-1])
        except ValueError:
            return np.nan
    elif size.endswith('K'):
        try:
            return float(size[:-1]) / 1000
        except ValueError:
            return np.nan
    else:
        try:
            return float(size)
        except ValueError:
            return np.nan

# now we apply it to the size column
play_store['Size'] = play_store['Size'].apply(converting_size_to_numeric)

# %%
# we wanted to make sure that all the sizes is calculated correctly that is under 1
play_store.rename(columns={'Size':'Size in MB'}, inplace=True) 
play_store[play_store['Size in MB']<1]
 # renaming the size column to size in MB instead of size to make it more clear
play_store['Size in MB'].fillna(play_store['Size in MB'].mean(), inplace=True)  # filling the missing values with the mean
pd.to_numeric(play_store['Size in MB'])  # converting the size in MB to numeric
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4672\1250078455.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   play_store['Size in MB'].fillna(play_store['Size in MB'].mean(), inplace=True)  # filling the missing values with the mean
# 0        19.00000
# 1        14.00000
# 2         8.70000
# 3        25.00000
# 4         2.80000
#            ...
# 10836    53.00000
# 10837     3.60000
# 10838     9.50000
# 10839    21.51653
# 10840    19.00000
# Name: Size in MB, Length: 10841, dtype: float64

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size in MB      10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
play_store.describe()
# Out:
#              Rating    Size in MB
# count  10841.000000  10841.000000
# mean       4.191973     21.516530
# std        0.478885     20.746538
# min        1.000000      0.008500
# 25%        4.100000      5.900000
# 50%        4.200000     18.000000
# 75%        4.500000     26.000000
# max        5.000000    100.000000

# %%
# now we want to fix the prices column
play_store[play_store['Price'] == '']  # wanted if there is any empty values in the price column
def dollars_to_numbers(price):
    if  isinstance(price, str):
        value = price.strip('$')
        return float(value)
    else:
        return price
    

play_store['Price'] = play_store['Price'].apply(dollars_to_numbers)

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size in MB      10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
play_store[play_store['Price']>0]  # making sure that the function worked correctly
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#          Rating Reviews  Size in MB  Installs  Type  Price Content Rating  \
# ...

# %%
# now fixing the category column
play_store['Category'].value_counts()  # checking the values in the category column
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
play_store[play_store['Category'].astype(str).str.contains('4')]  # checking if there is any wrong values in the category column
play_store.loc[[10472],:]  # checking the row have even some valid data in it or not
# as you have seen the row 10472 have wrong data in it so we will drop it
play_store.drop(10472, inplace=True)

# %%
play_store['Category'].value_counts()  # checking the values in the category column after dropping the wrong row
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
# fixing the android version column
play_store['Android Ver'].value_counts()  # checking the values in the android version column
play_store['Android Ver'].isnull().sum()  # checking the missing values in the android version column
play_store['Android Ver'].fillna(play_store['Android Ver'].mode()[0], inplace=True)  # filling the missing values with the mode of the column
play_store['Android Ver'].isnull().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4672\929958941.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   play_store['Android Ver'].fillna(play_store['Android Ver'].mode()[0], inplace=True)  # filling the missing values with the mode of the column
# 0

# %%
# fixing the android version column and turning it into numeric
string = '4.4 and up'
print(string.find(' and up'))  # just for experminting 
string = string.replace(' and up', '')
print(string)
def android_version_to_numeric(version):
    def convert_to_numeric(v):
        v = v.replace('W', '')
        parts = v.split('.')
        return float(parts[0] + '.' + ''.join(parts[1:]))
    
    if ' and up' in version:
        base_version = version.replace(' and up', '')
        latest_version = float('inf')  # turning the latest version to infinity
        return convert_to_numeric(base_version), latest_version
    elif ' - ' in version:
        base_version, latest_version = version.split(' - ')
        return convert_to_numeric(base_version), convert_to_numeric(latest_version)
    elif version == 'Varies with device':
        return np.nan, np.nan
    elif version == np.nan:
        return np.nan, np.nan
    else:
        return convert_to_numeric(version), convert_to_numeric(version)


play_store[['base_version', 'latest_version']] = play_store['Android Ver'].apply(
    lambda x: pd.Series(android_version_to_numeric(x))
)
# Out:
# 3
# 4.4

# %%
play_store['Android Ver'].value_counts()  # checking the values in the android version column after fixing it

play_store[play_store['Android Ver']== '7.0 - 7.1.1' ] # checking if the function is working in certain values
# Out:
#                   App   Category  Rating Reviews  Size in MB    Installs  \
# 1572  ZenUI Safeguard  LIFESTYLE     4.5     100         7.1  1,000,000+
#
#       Type  Price Content Rating     Genres Last Updated      Current Ver  \
# 1572  Free    0.0       Everyone  Lifestyle  May 9, 2018  1.0.0.21_180410
#
#       Android Ver  base_version  latest_version
# 1572  7.0 - 7.1.1           7.0            7.11

# %%
# now we work on detecting the outliers in the data
from datasist.structdata import detect_outliers
sns.boxplot(play_store['base_version'])
sns.stripplot(play_store['base_version'], color='orange')
# Out:
# <Axes: ylabel='base_version'>

# %%
play_store['Installs'].head(10)
# Out:
# 0        10,000+
# 1       500,000+
# 2     5,000,000+
# 3    50,000,000+
# 4       100,000+
# 5        50,000+
# 6        50,000+
# 7     1,000,000+
# 8     1,000,000+
# 9        10,000+
# Name: Installs, dtype: object

# %%
# we want to make the reviews column to numeric
# and i want to change the number of downloads to numeric
play_store['Reviews'] = pd.to_numeric(play_store['Reviews'], errors='coerce')
play_store['Installs'] = play_store['Installs'].str.replace(',', '')
play_store['Installs'] = play_store['Installs'].str.replace('+', '')
play_store['Installs'] = pd.to_numeric(play_store['Installs'], errors='coerce')
# now we want to check the the intger and float columns
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size in MB      10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10840 non-null  object
#  13  base_version    9478 non-null   float64
#  14  latest_version  9478 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
# now i want access the outliers and make a boxplot for the outliers
numerical_categories  =  ['Rating', 'Reviews', 'Size in MB', 'Installs', 'Price', 'base_version', 'latest_version']
plt.figure(figsize=(20, 10))
for index , column in enumerate(numerical_categories):
    plt.subplot(3, 3, index+1)
    sns.boxplot(play_store[column])
    sns.stripplot(play_store[column], color='orange')
    plt.title(column)
    plt.tight_layout()
    


# as we see there is no much outliers in the data so we will not remove any of the outliers

# %%
# now for the seocond part of the project we will answer some questions

# %%
# 1.the most expensive app in the play store
most_expensive = play_store[play_store['Price'] == play_store['Price'].max()]
most_expensive
# Out:
#                            App   Category  Rating  Reviews  Size in MB  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275         7.3
#
#       Installs  Type  Price Content Rating     Genres Last Updated  \
# 4367     10000  Paid  400.0       Everyone  Lifestyle  May 3, 2018
#
#      Current Ver Android Ver  base_version  latest_version
# 4367       1.0.1  4.1 and up           4.1             inf

# %%
# 2. what genre has the most apps
most_apps_genre = play_store['Genres'].value_counts().idxmax()
most_apps_genre
# Out:
# 'Tools'

# %%
# what is the average size of the free apps and the paid apps
grouped_by_type = play_store.groupby('Type')['Size in MB'].agg('mean')
print(f"the average size of the free apps is {grouped_by_type['Free']} MB")
print(f"the average size of the paid apps is {grouped_by_type['Paid']} MB")
# Out:
# the average size of the free apps is 21.67584453335654 MB
# the average size of the paid apps is 19.517325304811372 MB

# %%
# what is the top 5 expensive apps have the rating of 5
most_expensive55 = play_store[play_store['Rating'] == 5]
most_expensive55 = most_expensive55.sort_values(by="Price" , ascending=False).head(5)
most_expensive55
# Out:
#                                             App Category  Rating  Reviews  \
# 5489                  AP Art History Flashcards   FAMILY     5.0        1
# 7477                 USMLE Step 2 CK Flashcards   FAMILY     5.0        1
# 5246                      Hey AJ! It's Bedtime!   FAMILY     5.0        1
# 7204  TI-84 CE Graphing Calculator Manual TI 84   FAMILY     5.0        1
# 5482                 meStudying: AP English Lit   FAMILY     5.0        1
#
#       Size in MB  Installs  Type  Price Content Rating     Genres  \
# 5489      96.000        10  Paid  29.99     Mature 17+  Education
# 7477      40.000        10  Paid  19.99       Everyone  Education
# 5246      63.000        10  Paid   4.99       Everyone  Education
# 7204      27.000       100  Paid   4.99       Everyone  Education
# 5482       0.655        10  Paid   4.99       Everyone  Education
#
#           Last Updated Current Ver   Android Ver  base_version  latest_version
# ...

# %%
# how many apps that have more than 50000 reviews
play_store[play_store['Reviews']>50000].shape[0]    # using the indexing throught the shape of the data frame
# Out:
# 15

# %%
#What is the average price of the apps for each genre with each installs numbers
average_Genre_price= play_store.groupby('Genres')["Price"].agg('mean')  # the average price of the genres
average_Genre_install = play_store.groupby('Genres')["Installs"].agg('mean')  # the average installs of the genres
average_Genre = pd.concat([average_Genre_price, average_Genre_install], axis=1)
average_Genre
# Out:
#                                           Price      Installs
# Genres
# Action                                 0.228110  2.559463e+07
# Action;Action & Adventure              0.527647  5.177676e+06
# Adventure                              0.718400  5.422604e+06
# Adventure;Action & Adventure           0.767692  6.970385e+07
# Adventure;Brain Games                  2.990000  1.000000e+05
# ...                                         ...           ...
# Video Players & Editors                0.060462  3.587863e+07
# Video Players & Editors;Creativity     0.000000  5.000000e+06
# Video Players & Editors;Music & Video  0.000000  8.333333e+06
# Weather                                0.395366  5.196348e+06
# Word                                   0.000000  9.281812e+06
#
# [119 rows x 2 columns]
